# %% [markdown]
# **Perguntas para Reflexão:**

# %% [markdown]
# **1. Qual foi a média de valores de uma coluna específica?**
#
#     Tirei a média da coluna 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)' e a média da temperatura foi de 23.2°C
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **2. Qual o total de registros após a limpeza dos dados?**
#
#         O total de registros de dados depois do tratamento é de 8784 linhs e 10 colunas.
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Quais foram os valores máximos e mínimos identificados?
#
#         Devido ao tratamento dos dados todos o campos vazios do df foram preenchido com zero, por isso tive que tirar a minimo das colunas ignorando 0 para poder ter a minima dos dados,fiz um filtro das colunas pegando apenas as colunas tipo float para poder tirar a min
#
# ![image-3.png](attachment:image-3.png)
#
#         Filtrei as colunas tipo float para poder tirar as max
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **4. Quantos registros tinham valores nulos antes do tratamento?**
#
#       Antes do tratamento tinham 5005 valores nulos.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Qual foi o impacto da normalização de uma coluna específica?
#
#         Fiz a  normalizaçao da coluna 'UMIDADE RELATIVA DO AR, HORARIA (%)'.
#         Esse tratamento de anormalização transforma os dados em uma escala comum, e facilita a comparação as colunas e garante que todas as colunas contribuam igualmente para os cálculos.

# %% [markdown]
# 6. Que padrões emergiram após a análise dos dados?
#
# A temperatura apresenta uma variação clara ao longo do ano, com picos geralmente nos meses mais quentes e valores mais baixos nos meses mais frios.
# A umidade apresenta uma variação menor em comparação com a temperatura, mantendo-se relativamente constante ao longo do ano.
#  O gráfico mostra claramente os meses em que a temperatura foi mais alta e mais baixa,essa informação é útil para entender os períodos mais quentes e mais frios do ano

# %% [markdown]
# 7. Como os dados foram agrupados e quais insights foram gerados?
#
# Agrupei os dados usando a função groupby para poder fazer comparar diferentes colunas do df

# %% [markdown]
# 8. Quais visualizações forneceram as informações mais valiosas?
#
#
# A visualização dos gráficos em si, apesar de não conseguir ainda descrever um gráfico de forma eficente ter uma dado em forma visual é algo que facilita o entendimento para podermos fazer a análise.

# %% [markdown]
# 9. Como o uso de SQL contribuiu para a organização dos resultados?
#
#
# Contruiu para que eu fazesse os ajustes necessário para poder ter um os dados mais limpo e organizado para que código fosse eficiente para a análise como por exmpelo:
# filtrar os dados eliminando colunas desnecessarias para análise de acordo com critérios específicos, isolando apenas as informações relevantes.
# Agrupando os dados,fazendo calculos de estatisticas soma,média etc

# %% [markdown]
# 10. De que forma os gráficos ajudaram na compreensão dos dados?
#
# Confesso que ainda não consigo fazer uma análise de gráfico, é claro que olhando consigo identificar qual a max ou min, qual mês choveu mais e qual choveu menos, mas gostaria e pretendo fazer análises mais aprofundadas que possa tirar mais ideias e conclusões

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Extração
# 1. **Extração de Dados:**
#    - Inicie o projeto extraindo dados de um arquivo CSV.
#
# 2. **Inspeção Inicial:**
#    - Revise o conteúdo dos dados extraídos, observando as primeiras e últimas linhas, a forma e a descrição geral dos dados, e os tipos de dados.
#
# 3. **Identificação e Tratamento de Valores Faltantes:**
#    - Identifique a presença de valores nulos e trate-os adequadamente, seja removendo, preenchendo ou substituindo esses valores.

# %%
file_path = '/content/drive/My Drive/INMET_MS_ITAQUIRAI_2020.CSV'
df = pd.read_csv(file_path, encoding='latin1',skiprows=8, delimiter=';')
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                               ,6
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                970
# 1                                              970,2
# 2                                              969,8
# 3                                              970,1
# 4                                              970,2
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                             970
# 1                                           970,2
# 2                                           970,2
# 3                                           970,1
# 4                                           970,5
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                            969,5                     NaN
# 1                                              970                     2,9
# 2                                            969,8                     1,6
# 3                                            969,8                      ,6
# 4                                            970,1                     NaN
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         23,1
# 1                                         23,7
# 2                                           24
# 3                                         24,3
# 4                                         23,8
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                 22,6
# 1                                 21,7
# 2                                 21,8
# 3                                 21,4
# 4                                 21,7
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       23,1
# 1                                       23,7
# 2                                       24,4
# 3                                       25,1
# 4                                       24,3
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       22,6
# 1                                         23
# 2                                       23,7
# 3                                         24
# 4                                       23,7
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                             22,8
# 1                                             22,5
# 2                                             21,9
# 3                                               22
# 4                                             21,8
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                             21,6
# 1                                             21,6
# 2                                             21,2
# 3                                             21,2
# 4                                             21,4
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      98.0
# 1                                      97.0
# 2                                      88.0
# 3                                      88.0
# 4                                      89.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      94.0
# 1                                      88.0
# 2                                      83.0
# 3                                      80.0
# 4                                      83.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 97.0                                  11.0
# 1                                 88.0                                  10.0
# 2                                 88.0                                 345.0
# 3                                 83.0                                 332.0
# 4                                 89.0                                 316.0
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                        3,2                             1,9          NaN
# 1                        4,6                             1,3          NaN
# 2                        3,2                              ,6          NaN
# 3                        4,8                             1,5          NaN
# 4                        3,3                              ,2          NaN

# %%
df.tail()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 8779  2020/12/31  1900 UTC                               ,4
# 8780  2020/12/31  2000 UTC                                0
# 8781  2020/12/31  2100 UTC                                0
# 8782  2020/12/31  2200 UTC                                0
# 8783  2020/12/31  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 8779                                              972,6
# 8780                                              970,4
# 8781                                              970,7
# 8782                                              972,4
# 8783                                              974,1
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8779                                           973,3
# 8780                                           972,6
# 8781                                           970,7
# 8782                                           972,4
# 8783                                           974,1
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 8779                                            972,6                   775,9
# 8780                                            970,4                   837,8
# 8781                                            970,1                   524,7
# 8782                                            970,7                   256,5
# 8783                                            972,4                     9,6
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 8779                                         23,1
# 8780                                         24,2
# 8781                                         24,9
# 8782                                         24,2
# 8783                                         23,5
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 8779                                 22,7
# 8780                                 22,7
# 8781                                   23
# 8782                                 22,1
# 8783                                 22,5
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 8779                                       23,3
# 8780                                       24,4
# 8781                                       24,9
# 8782                                       25,1
# 8783                                       24,2
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 8779                                       21,7
# 8780                                       23,1
# 8781                                       24,1
# 8782                                       24,2
# 8783                                       23,4
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 8779                                              NaN
# 8780                                             22,8
# 8781                                             23,3
# 8782                                             23,1
# 8783                                             22,5
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 8779                                              NaN
# 8780                                             22,1
# 8781                                             22,5
# 8782                                             22,1
# 8783                                               22
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 8779                                       NaN
# 8780                                      97.0
# 8781                                      93.0
# 8782                                      89.0
# 8783                                      94.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 8779                                       NaN
# 8780                                      89.0
# 8781                                      89.0
# 8782                                      87.0
# 8783                                      88.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 8779                                 97.0
# 8780                                 91.0
# 8781                                 89.0
# 8782                                 88.0
# 8783                                 94.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 8779                                  32.0                        6,6
# 8780                                 355.0                        2,8
# 8781                                 315.0                        4,2
# 8782                                 291.0                        4,8
# 8783                                 132.0                        3,9
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 8779                             1,2          NaN
# 8780                              ,8          NaN
# 8781                             1,2          NaN
# 8782                              ,9          NaN
# 8783                              ,9          NaN

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE RELATIVA DO AR, HORARIA (%)                      float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     float64
# VENTO, RAJADA MAXIMA (m/s)                                object
# VENTO, VELOCIDADE HORARIA (m/s)                           object
# Unnamed: 19                                              float64
# dtype: object

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                               ,6
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                970
# 1                                              970,2
# 2                                              969,8
# 3                                              970,1
# 4                                              970,2
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                             970
# 1                                           970,2
# 2                                           970,2
# 3                                           970,1
# 4                                           970,5
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                            969,5                     NaN
# 1                                              970                     2,9
# 2                                            969,8                     1,6
# 3                                            969,8                      ,6
# 4                                            970,1                     NaN
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         23,1
# 1                                         23,7
# 2                                           24
# 3                                         24,3
# 4                                         23,8
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                 22,6
# 1                                 21,7
# 2                                 21,8
# 3                                 21,4
# 4                                 21,7
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       23,1
# 1                                       23,7
# 2                                       24,4
# 3                                       25,1
# 4                                       24,3
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       22,6
# 1                                         23
# 2                                       23,7
# 3                                         24
# 4                                       23,7
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                             22,8
# 1                                             22,5
# 2                                             21,9
# 3                                               22
# 4                                             21,8
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                             21,6
# 1                                             21,6
# 2                                             21,2
# 3                                             21,2
# 4                                             21,4
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      98.0
# 1                                      97.0
# 2                                      88.0
# 3                                      88.0
# 4                                      89.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      94.0
# 1                                      88.0
# 2                                      83.0
# 3                                      80.0
# 4                                      83.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 97.0                                  11.0
# 1                                 88.0                                  10.0
# 2                                 88.0                                 345.0
# 3                                 83.0                                 332.0
# 4                                 89.0                                 316.0
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                        3,2                             1,9          NaN
# 1                        4,6                             1,3          NaN
# 2                        3,2                              ,6          NaN
# 3                        4,8                             1,5          NaN
# 4                        3,3                              ,2          NaN

# %%
df.tail()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 8779  2020/12/31  1900 UTC                               ,4
# 8780  2020/12/31  2000 UTC                                0
# 8781  2020/12/31  2100 UTC                                0
# 8782  2020/12/31  2200 UTC                                0
# 8783  2020/12/31  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 8779                                              972,6
# 8780                                              970,4
# 8781                                              970,7
# 8782                                              972,4
# 8783                                              974,1
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8779                                           973,3
# 8780                                           972,6
# 8781                                           970,7
# 8782                                           972,4
# 8783                                           974,1
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 8779                                            972,6                   775,9
# 8780                                            970,4                   837,8
# 8781                                            970,1                   524,7
# 8782                                            970,7                   256,5
# 8783                                            972,4                     9,6
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 8779                                         23,1
# 8780                                         24,2
# 8781                                         24,9
# 8782                                         24,2
# 8783                                         23,5
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 8779                                 22,7
# 8780                                 22,7
# 8781                                   23
# 8782                                 22,1
# 8783                                 22,5
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 8779                                       23,3
# 8780                                       24,4
# 8781                                       24,9
# 8782                                       25,1
# 8783                                       24,2
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 8779                                       21,7
# 8780                                       23,1
# 8781                                       24,1
# 8782                                       24,2
# 8783                                       23,4
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 8779                                              NaN
# 8780                                             22,8
# 8781                                             23,3
# 8782                                             23,1
# 8783                                             22,5
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 8779                                              NaN
# 8780                                             22,1
# 8781                                             22,5
# 8782                                             22,1
# 8783                                               22
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 8779                                       NaN
# 8780                                      97.0
# 8781                                      93.0
# 8782                                      89.0
# 8783                                      94.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 8779                                       NaN
# 8780                                      89.0
# 8781                                      89.0
# 8782                                      87.0
# 8783                                      88.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 8779                                 97.0
# 8780                                 91.0
# 8781                                 89.0
# 8782                                 88.0
# 8783                                 94.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 8779                                  32.0                        6,6
# 8780                                 355.0                        2,8
# 8781                                 315.0                        4,2
# 8782                                 291.0                        4,8
# 8783                                 132.0                        3,9
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 8779                             1,2          NaN
# 8780                              ,8          NaN
# 8781                             1,2          NaN
# 8782                              ,9          NaN
# 8783                              ,9          NaN

# %%
df = df.replace(',','.',regex=True)

# %%
df = df[['Data','Hora UTC','PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)','TEMPERATURA DO PONTO DE ORVALHO (°C)','UMIDADE RELATIVA DO AR, HORARIA (%)', 'RADIACAO GLOBAL (Kj/m²)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))' ,'VENTO, VELOCIDADE HORARIA (m/s)']]

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                               .6
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         23.1
# 1                                         23.7
# 2                                           24
# 3                                         24.3
# 4                                         23.8
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                 22.6                                 97.0
# 1                                 21.7                                 88.0
# 2                                 21.8                                 88.0
# 3                                 21.4                                 83.0
# 4                                 21.7                                 89.0
#
#   RADIACAO GLOBAL (Kj/m²)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                     NaN                                  11.0
# 1                     2.9                                  10.0
# 2                     1.6                                 345.0
# 3                      .6                                 332.0
# 4                     NaN                                 316.0
#
#   VENTO, VELOCIDADE HORARIA (m/s)
# 0                             1.9
# 1                             1.3
# 2                              .6
# 3                             1.5
# 4                              .2

# %% [markdown]
# Limpeza dos dados: Retirar nulos, normalizar percentual e alterar as virgulas para pontos e ajustar a data e hora
#
# #### **Tratamento de Dados**
#
# 1. **Ajustes e Limpeza:**
#    - Organize e limpe os dados, removendo duplicatas e normalizando quando necessário.
#
# 2. **Renomeação e Ajuste de Colunas:**
#    - Renomeie colunas e ajuste os tipos de dados conforme necessário para garantir a consistência e clareza.
#
# 3. **Transformações e Criação de Novas Colunas:**
#    - Realize transformações relevantes nos dados, como criar novas colunas derivadas de outras existentes.

# %%
df_5 = df.isnull().sum()
df_5
# Out:
# Data                                               0
# Hora UTC                                           0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                   6
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)       6
# TEMPERATURA DO PONTO DE ORVALHO (°C)             466
# UMIDADE RELATIVA DO AR, HORARIA (%)              466
# RADIACAO GLOBAL (Kj/m²)                         4049
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))               6
# VENTO, VELOCIDADE HORARIA (m/s)                    6
# dtype: int64

# %%
df.shape
# Out:
# (8784, 9)

# %%
df.head(10)
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                               .6
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
# 5  2020/01/01  0500 UTC                                0
# 6  2020/01/01  0600 UTC                                0
# 7  2020/01/01  0700 UTC                                0
# 8  2020/01/01  0800 UTC                                0
# 9  2020/01/01  0900 UTC                                0
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         23.1
# 1                                         23.7
# 2                                           24
# 3                                         24.3
# 4                                         23.8
# 5                                         23.5
# 6                                         22.7
# 7                                         22.9
# 8                                         22.9
# 9                                         22.9
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                 22.6                                 97.0
# 1                                 21.7                                 88.0
# 2                                 21.8                                 88.0
# 3                                 21.4                                 83.0
# 4                                 21.7                                 89.0
# 5                                 22.3                                 93.0
# 6                                 22.4                                 98.0
# 7                                  NaN                                  NaN
# 8                                  NaN                                  NaN
# 9                                 22.5                                 97.0
#
#   RADIACAO GLOBAL (Kj/m²)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                     NaN                                  11.0
# 1                     2.9                                  10.0
# 2                     1.6                                 345.0
# 3                      .6                                 332.0
# 4                     NaN                                 316.0
# 5                     NaN                                 141.0
# 6                     NaN                                  40.0
# 7                     NaN                                  36.0
# 8                     NaN                                  68.0
# 9                     2.3                                 358.0
#
#   VENTO, VELOCIDADE HORARIA (m/s)
# 0                             1.9
# 1                             1.3
# 2                              .6
# 3                             1.5
# 4                              .2
# 5                               0
# 6                               0
# 7                              .9
# 8                               0
# 9                               0

# %%
df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = pd.to_numeric(df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], errors='coerce')
df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = pd.to_numeric(df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], errors='coerce')
df['TEMPERATURA DO PONTO DE ORVALHO (°C)'] = pd.to_numeric(df['TEMPERATURA DO PONTO DE ORVALHO (°C)'], errors='coerce')
df['RADIACAO GLOBAL (Kj/m²)'] = pd.to_numeric(df['RADIACAO GLOBAL (Kj/m²)'], errors='coerce')
df['VENTO, VELOCIDADE HORARIA (m/s)'] = pd.to_numeric(df['VENTO, VELOCIDADE HORARIA (m/s)'], errors='coerce')

#outra opção
# coluna_objeto = df.select_dtypes(include=['object']).columns
# coluna_objeto = coluna_objeto.drop(['Data', 'Hora UTC'])
# for coluna in coluna_objeto:
#     df[coluna] = pd.to_numeric(df[coluna], errors='coerce')
# print(df.dtypes)

# %%
df.dtypes
# Out:
# Data                                             object
# Hora UTC                                         object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                float64
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)    float64
# TEMPERATURA DO PONTO DE ORVALHO (°C)            float64
# UMIDADE RELATIVA DO AR, HORARIA (%)             float64
# RADIACAO GLOBAL (Kj/m²)                         float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))            float64
# VENTO, VELOCIDADE HORARIA (m/s)                 float64
# dtype: object

# %%
# df = df.dropna() # remover linhas com valores nulos ou faltantes

df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].fillna(0)
df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Data                                               0
# Hora UTC                                           0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                   0
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)       0
# TEMPERATURA DO PONTO DE ORVALHO (°C)             466
# UMIDADE RELATIVA DO AR, HORARIA (%)              466
# RADIACAO GLOBAL (Kj/m²)                         4049
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))               6
# VENTO, VELOCIDADE HORARIA (m/s)                    6
# dtype: int64

# %%
df = df.fillna(0)
df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2020/01/01  0000 UTC                               0.6
# 1     2020/01/01  0100 UTC                               0.0
# 2     2020/01/01  0200 UTC                               0.0
# 3     2020/01/01  0300 UTC                               0.0
# 4     2020/01/01  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8779  2020/12/31  1900 UTC                               0.4
# 8780  2020/12/31  2000 UTC                               0.0
# 8781  2020/12/31  2100 UTC                               0.0
# 8782  2020/12/31  2200 UTC                               0.0
# 8783  2020/12/31  2300 UTC                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    97.0                      0.0
# 1                                    88.0                      2.9
# 2                                    88.0                      1.6
# 3                                    83.0                      0.6
# 4                                    89.0                      0.0
# ...                                   ...                      ...
# 8779                                 97.0                    775.9
# 8780                                 91.0                    837.8
# 8781                                 89.0                    524.7
# 8782                                 88.0                    256.5
# 8783                                 94.0                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
# [8784 rows x 9 columns]

# %%
df['UMIDADE RELATIVA DO AR, HORARIA (%)'] = (df['UMIDADE RELATIVA DO AR, HORARIA (%)'] - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min()) / (df['UMIDADE RELATIVA DO AR, HORARIA (%)'].max() - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min())
df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2020/01/01  0000 UTC                               0.6
# 1     2020/01/01  0100 UTC                               0.0
# 2     2020/01/01  0200 UTC                               0.0
# 3     2020/01/01  0300 UTC                               0.0
# 4     2020/01/01  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8779  2020/12/31  1900 UTC                               0.4
# 8780  2020/12/31  2000 UTC                               0.0
# 8781  2020/12/31  2100 UTC                               0.0
# 8782  2020/12/31  2200 UTC                               0.0
# 8783  2020/12/31  2300 UTC                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
# [8784 rows x 9 columns]

# %%
df['Data'] = pd.to_datetime(df['Data'], format='%Y/%m/%d')
df['Data'] = df['Data'].dt.strftime('%d/%m/%Y')
df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     01/01/2020  0000 UTC                               0.6
# 1     01/01/2020  0100 UTC                               0.0
# 2     01/01/2020  0200 UTC                               0.0
# 3     01/01/2020  0300 UTC                               0.0
# 4     01/01/2020  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8779  31/12/2020  1900 UTC                               0.4
# 8780  31/12/2020  2000 UTC                               0.0
# 8781  31/12/2020  2100 UTC                               0.0
# 8782  31/12/2020  2200 UTC                               0.0
# 8783  31/12/2020  2300 UTC                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
# [8784 rows x 9 columns]

# %%
#Substituir numeros nulos por zero.

df = df.dropna()

# %%
df.head()
# Out:
#          Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2020  0000 UTC                               0.6
# 1  01/01/2020  0100 UTC                               0.0
# 2  01/01/2020  0200 UTC                               0.0
# 3  01/01/2020  0300 UTC                               0.0
# 4  01/01/2020  0400 UTC                               0.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          23.1
# 1                                          23.7
# 2                                          24.0
# 3                                          24.3
# 4                                          23.8
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                  22.6                                 0.97
# 1                                  21.7                                 0.88
# 2                                  21.8                                 0.88
# 3                                  21.4                                 0.83
# 4                                  21.7                                 0.89
#
#    RADIACAO GLOBAL (Kj/m²)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                      0.0                                  11.0
# 1                      2.9                                  10.0
# 2                      1.6                                 345.0
# 3                      0.6                                 332.0
# 4                      0.0                                 316.0
#
#    VENTO, VELOCIDADE HORARIA (m/s)
# 0                              1.9
# 1                              1.3
# 2                              0.6
# 3                              1.5
# 4                              0.2

# %%
df.dtypes
# Out:
# Data                                             object
# Hora UTC                                         object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                float64
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)    float64
# TEMPERATURA DO PONTO DE ORVALHO (°C)            float64
# UMIDADE RELATIVA DO AR, HORARIA (%)             float64
# RADIACAO GLOBAL (Kj/m²)                         float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))            float64
# VENTO, VELOCIDADE HORARIA (m/s)                 float64
# dtype: object

# %%
df.head()
# Out:
#          Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2020  0000 UTC                               0.6
# 1  01/01/2020  0100 UTC                               0.0
# 2  01/01/2020  0200 UTC                               0.0
# 3  01/01/2020  0300 UTC                               0.0
# 4  01/01/2020  0400 UTC                               0.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          23.1
# 1                                          23.7
# 2                                          24.0
# 3                                          24.3
# 4                                          23.8
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                  22.6                                 0.97
# 1                                  21.7                                 0.88
# 2                                  21.8                                 0.88
# 3                                  21.4                                 0.83
# 4                                  21.7                                 0.89
#
#    RADIACAO GLOBAL (Kj/m²)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                      0.0                                  11.0
# 1                      2.9                                  10.0
# 2                      1.6                                 345.0
# 3                      0.6                                 332.0
# 4                      0.0                                 316.0
#
#    VENTO, VELOCIDADE HORARIA (m/s)
# 0                              1.9
# 1                              1.3
# 2                              0.6
# 3                              1.5
# 4                              0.2

# %%
# df = df.dropna() # remover linhas com valores nulos ou faltantes

df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].fillna(0)
df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Data                                            0
# Hora UTC                                        0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                0
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)    0
# TEMPERATURA DO PONTO DE ORVALHO (°C)            0
# UMIDADE RELATIVA DO AR, HORARIA (%)             0
# RADIACAO GLOBAL (Kj/m²)                         0
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))            0
# VENTO, VELOCIDADE HORARIA (m/s)                 0
# dtype: int64

# %%
df = df.fillna(0)
df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     01/01/2020  0000 UTC                               0.6
# 1     01/01/2020  0100 UTC                               0.0
# 2     01/01/2020  0200 UTC                               0.0
# 3     01/01/2020  0300 UTC                               0.0
# 4     01/01/2020  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8779  31/12/2020  1900 UTC                               0.4
# 8780  31/12/2020  2000 UTC                               0.0
# 8781  31/12/2020  2100 UTC                               0.0
# 8782  31/12/2020  2200 UTC                               0.0
# 8783  31/12/2020  2300 UTC                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
# [8784 rows x 9 columns]

# %%
df['UMIDADE RELATIVA DO AR, HORARIA (%)'] = (df['UMIDADE RELATIVA DO AR, HORARIA (%)'] - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min()) / (df['UMIDADE RELATIVA DO AR, HORARIA (%)'].max() - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min())
df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     01/01/2020  0000 UTC                               0.6
# 1     01/01/2020  0100 UTC                               0.0
# 2     01/01/2020  0200 UTC                               0.0
# 3     01/01/2020  0300 UTC                               0.0
# 4     01/01/2020  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8779  31/12/2020  1900 UTC                               0.4
# 8780  31/12/2020  2000 UTC                               0.0
# 8781  31/12/2020  2100 UTC                               0.0
# 8782  31/12/2020  2200 UTC                               0.0
# 8783  31/12/2020  2300 UTC                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
# [8784 rows x 9 columns]

# %%
df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     01/01/2020  0000 UTC                               0.6
# 1     01/01/2020  0100 UTC                               0.0
# 2     01/01/2020  0200 UTC                               0.0
# 3     01/01/2020  0300 UTC                               0.0
# 4     01/01/2020  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8779  31/12/2020  1900 UTC                               0.4
# 8780  31/12/2020  2000 UTC                               0.0
# 8781  31/12/2020  2100 UTC                               0.0
# 8782  31/12/2020  2200 UTC                               0.0
# 8783  31/12/2020  2300 UTC                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
# [8784 rows x 9 columns]

# %%
df.dtypes
# Out:
# Data                                             object
# Hora UTC                                         object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                float64
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)    float64
# TEMPERATURA DO PONTO DE ORVALHO (°C)            float64
# UMIDADE RELATIVA DO AR, HORARIA (%)             float64
# RADIACAO GLOBAL (Kj/m²)                         float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))            float64
# VENTO, VELOCIDADE HORARIA (m/s)                 float64
# dtype: object

# %%
df['Hora UTC'] = pd.to_datetime(df['Hora UTC'], format='%H%M UTC', errors='coerce').dt.strftime('%H:%M')

# %%
df
# Out:
#             Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     01/01/2020    00:00                               0.6
# 1     01/01/2020    01:00                               0.0
# 2     01/01/2020    02:00                               0.0
# 3     01/01/2020    03:00                               0.0
# 4     01/01/2020    04:00                               0.0
# ...          ...      ...                               ...
# 8779  31/12/2020    19:00                               0.4
# 8780  31/12/2020    20:00                               0.0
# 8781  31/12/2020    21:00                               0.0
# 8782  31/12/2020    22:00                               0.0
# 8783  31/12/2020    23:00                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
# [8784 rows x 9 columns]

# %%
df['Data e Hora'] = df['Data'] + ' ' + df['Hora UTC']

# %%
df
# Out:
#             Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     01/01/2020    00:00                               0.6
# 1     01/01/2020    01:00                               0.0
# 2     01/01/2020    02:00                               0.0
# 3     01/01/2020    03:00                               0.0
# 4     01/01/2020    04:00                               0.0
# ...          ...      ...                               ...
# 8779  31/12/2020    19:00                               0.4
# 8780  31/12/2020    20:00                               0.0
# 8781  31/12/2020    21:00                               0.0
# 8782  31/12/2020    22:00                               0.0
# 8783  31/12/2020    23:00                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)  \
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
#            Data e Hora
# 0     01/01/2020 00:00
# 1     01/01/2020 01:00
# 2     01/01/2020 02:00
# 3     01/01/2020 03:00
# 4     01/01/2020 04:00
# ...                ...
# 8779  31/12/2020 19:00
# 8780  31/12/2020 20:00
# 8781  31/12/2020 21:00
# 8782  31/12/2020 22:00
# 8783  31/12/2020 23:00
#
# [8784 rows x 10 columns]

# %%
df['Data e Hora'] = pd.to_datetime(df['Data e Hora'], format='%d/%m/%Y %H:%M', errors='coerce')

# %%
df.head(10)
# Out:
#          Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2020    00:00                               0.6
# 1  01/01/2020    01:00                               0.0
# 2  01/01/2020    02:00                               0.0
# 3  01/01/2020    03:00                               0.0
# 4  01/01/2020    04:00                               0.0
# 5  01/01/2020    05:00                               0.0
# 6  01/01/2020    06:00                               0.0
# 7  01/01/2020    07:00                               0.0
# 8  01/01/2020    08:00                               0.0
# 9  01/01/2020    09:00                               0.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          23.1
# 1                                          23.7
# 2                                          24.0
# 3                                          24.3
# 4                                          23.8
# 5                                          23.5
# 6                                          22.7
# 7                                          22.9
# 8                                          22.9
# 9                                          22.9
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                  22.6                                 0.97
# 1                                  21.7                                 0.88
# 2                                  21.8                                 0.88
# 3                                  21.4                                 0.83
# 4                                  21.7                                 0.89
# 5                                  22.3                                 0.93
# 6                                  22.4                                 0.98
# 7                                   0.0                                 0.00
# 8                                   0.0                                 0.00
# 9                                  22.5                                 0.97
#
#    RADIACAO GLOBAL (Kj/m²)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                      0.0                                  11.0
# 1                      2.9                                  10.0
# 2                      1.6                                 345.0
# 3                      0.6                                 332.0
# 4                      0.0                                 316.0
# 5                      0.0                                 141.0
# 6                      0.0                                  40.0
# 7                      0.0                                  36.0
# 8                      0.0                                  68.0
# 9                      2.3                                 358.0
#
#    VENTO, VELOCIDADE HORARIA (m/s)         Data e Hora
# 0                              1.9 2020-01-01 00:00:00
# 1                              1.3 2020-01-01 01:00:00
# 2                              0.6 2020-01-01 02:00:00
# 3                              1.5 2020-01-01 03:00:00
# 4                              0.2 2020-01-01 04:00:00
# 5                              0.0 2020-01-01 05:00:00
# 6                              0.0 2020-01-01 06:00:00
# 7                              0.9 2020-01-01 07:00:00
# 8                              0.0 2020-01-01 08:00:00
# 9                              0.0 2020-01-01 09:00:00

# %%
df['Data e Hora BR'] = df['Data e Hora'].dt.tz_localize('UTC').dt.tz_convert('America/Sao_Paulo')

# %%
df.head(10)
# Out:
#          Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2020    00:00                               0.6
# 1  01/01/2020    01:00                               0.0
# 2  01/01/2020    02:00                               0.0
# 3  01/01/2020    03:00                               0.0
# 4  01/01/2020    04:00                               0.0
# 5  01/01/2020    05:00                               0.0
# 6  01/01/2020    06:00                               0.0
# 7  01/01/2020    07:00                               0.0
# 8  01/01/2020    08:00                               0.0
# 9  01/01/2020    09:00                               0.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          23.1
# 1                                          23.7
# 2                                          24.0
# 3                                          24.3
# 4                                          23.8
# 5                                          23.5
# 6                                          22.7
# 7                                          22.9
# 8                                          22.9
# 9                                          22.9
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                  22.6                                 0.97
# 1                                  21.7                                 0.88
# 2                                  21.8                                 0.88
# 3                                  21.4                                 0.83
# 4                                  21.7                                 0.89
# 5                                  22.3                                 0.93
# 6                                  22.4                                 0.98
# 7                                   0.0                                 0.00
# 8                                   0.0                                 0.00
# 9                                  22.5                                 0.97
#
#    RADIACAO GLOBAL (Kj/m²)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                      0.0                                  11.0
# 1                      2.9                                  10.0
# 2                      1.6                                 345.0
# 3                      0.6                                 332.0
# 4                      0.0                                 316.0
# 5                      0.0                                 141.0
# 6                      0.0                                  40.0
# 7                      0.0                                  36.0
# 8                      0.0                                  68.0
# 9                      2.3                                 358.0
#
#    VENTO, VELOCIDADE HORARIA (m/s)         Data e Hora  \
# 0                              1.9 2020-01-01 00:00:00
# 1                              1.3 2020-01-01 01:00:00
# 2                              0.6 2020-01-01 02:00:00
# 3                              1.5 2020-01-01 03:00:00
# 4                              0.2 2020-01-01 04:00:00
# 5                              0.0 2020-01-01 05:00:00
# 6                              0.0 2020-01-01 06:00:00
# 7                              0.9 2020-01-01 07:00:00
# 8                              0.0 2020-01-01 08:00:00
# 9                              0.0 2020-01-01 09:00:00
#
#              Data e Hora BR
# 0 2019-12-31 21:00:00-03:00
# 1 2019-12-31 22:00:00-03:00
# 2 2019-12-31 23:00:00-03:00
# 3 2020-01-01 00:00:00-03:00
# 4 2020-01-01 01:00:00-03:00
# 5 2020-01-01 02:00:00-03:00
# 6 2020-01-01 03:00:00-03:00
# 7 2020-01-01 04:00:00-03:00
# 8 2020-01-01 05:00:00-03:00
# 9 2020-01-01 06:00:00-03:00

# %%
df['Data e Hora BR'] = df['Data e Hora BR'].dt.strftime('%d/%m/%Y %H:%M')

# %%
df.head()
# Out:
#          Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2020    00:00                               0.6
# 1  01/01/2020    01:00                               0.0
# 2  01/01/2020    02:00                               0.0
# 3  01/01/2020    03:00                               0.0
# 4  01/01/2020    04:00                               0.0
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          23.1
# 1                                          23.7
# 2                                          24.0
# 3                                          24.3
# 4                                          23.8
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                  22.6                                 0.97
# 1                                  21.7                                 0.88
# 2                                  21.8                                 0.88
# 3                                  21.4                                 0.83
# 4                                  21.7                                 0.89
#
#    RADIACAO GLOBAL (Kj/m²)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                      0.0                                  11.0
# 1                      2.9                                  10.0
# 2                      1.6                                 345.0
# 3                      0.6                                 332.0
# 4                      0.0                                 316.0
#
#    VENTO, VELOCIDADE HORARIA (m/s)         Data e Hora    Data e Hora BR
# 0                              1.9 2020-01-01 00:00:00  31/12/2019 21:00
# 1                              1.3 2020-01-01 01:00:00  31/12/2019 22:00
# 2                              0.6 2020-01-01 02:00:00  31/12/2019 23:00
# 3                              1.5 2020-01-01 03:00:00  01/01/2020 00:00
# 4                              0.2 2020-01-01 04:00:00  01/01/2020 01:00

# %% [markdown]
# Analise de Dados

# %%
df.describe()
# Out:
#        PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# count                       8784.000000
# mean                           0.151480
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                           44.800000
# std                            1.375679
#
#        TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# count                                   8784.000000
# mean                                      23.172837
# min                                        0.000000
# 25%                                       19.500000
# 50%                                       23.100000
# 75%                                       27.100000
# max                                       40.600000
# std                                        5.725963
#
#        TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# count                           8784.000000
# mean                              15.201423
# min                                0.000000
# 25%                               12.400000
# 50%                               16.000000
# 75%                               19.300000
# max                               25.800000
# std                                5.592551
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# count                          8784.000000              8784.000000
# mean                              0.632725               759.334028
# min                               0.000000                 0.000000
# 25%                               0.490000                 0.000000
# 50%                               0.670000                23.100000
# 75%                               0.820000              1434.250000
# max                               1.000000              4085.400000
# std                               0.241409              1077.034129
#
#        VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)  \
# count                           8784.000000                      8784.000000
# mean                             184.889458                         1.939447
# min                                0.000000                         0.000000
# 25%                              133.000000                         0.900000
# 50%                              171.000000                         1.800000
# 75%                              254.000000                         2.800000
# max                              360.000000                        11.900000
# std                               81.784719                         1.405233
#
#                Data e Hora
# count                 8784
# mean   2020-07-01 23:30:00
# min    2020-01-01 00:00:00
# 25%    2020-04-01 11:45:00
# 50%    2020-07-01 23:30:00
# 75%    2020-10-01 11:15:00
# max    2020-12-31 23:00:00
# std                    NaN

# %%
df.set_index('Data e Hora BR', inplace=True)

df[['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
    'UMIDADE RELATIVA DO AR, HORARIA (%)']].plot(subplots=True)

plt.suptitle('Séries Temporais das Variáveis')
plt.show()

# %%
plt.scatter(df['Data e Hora'] ,df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'],
            c=df['UMIDADE RELATIVA DO AR, HORARIA (%)'],
            cmap='viridis',
            alpha=0.7,
            edgecolors='w')
plt.colorbar(label='Umidade Relativa do Ar (%)')

plt.title('Temperatura do Ar x Umidade Relativa do Ar')
plt.xlabel('Hora e Data')
plt.ylabel('TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)')
plt.show()

# %%
correlacao = df.corr

correlacao
# Out:
# <bound method DataFrame.corr of                         Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# Data e Hora BR
# 31/12/2019 21:00  01/01/2020    00:00                               0.6
# 31/12/2019 22:00  01/01/2020    01:00                               0.0
# 31/12/2019 23:00  01/01/2020    02:00                               0.0
# 01/01/2020 00:00  01/01/2020    03:00                               0.0
# 01/01/2020 01:00  01/01/2020    04:00                               0.0
# ...                      ...      ...                               ...
# 31/12/2020 16:00  31/12/2020    19:00                               0.4
# 31/12/2020 17:00  31/12/2020    20:00                               0.0
# 31/12/2020 18:00  31/12/2020    21:00                               0.0
# 31/12/2020 19:00  31/12/2020    22:00                               0.0
# 31/12/2020 20:00  31/12/2020    23:00                               0.0
#
#                   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# Data e Hora BR
# 31/12/2019 21:00                                          23.1
# 31/12/2019 22:00                                          23.7
# 31/12/2019 23:00                                          24.0
# 01/01/2020 00:00                                          24.3
# 01/01/2020 01:00                                          23.8
# ...                                                        ...
# 31/12/2020 16:00                                          23.1
# 31/12/2020 17:00                                          24.2
# 31/12/2020 18:00                                          24.9
# 31/12/2020 19:00                                          24.2
# 31/12/2020 20:00                                          23.5
#
#                   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# Data e Hora BR
# 31/12/2019 21:00                                  22.6
# 31/12/2019 22:00                                  21.7
# 31/12/2019 23:00                                  21.8
# 01/01/2020 00:00                                  21.4
# 01/01/2020 01:00                                  21.7
# ...                                                ...
# 31/12/2020 16:00                                  22.7
# 31/12/2020 17:00                                  22.7
# 31/12/2020 18:00                                  23.0
# 31/12/2020 19:00                                  22.1
# 31/12/2020 20:00                                  22.5
#
#                   UMIDADE RELATIVA DO AR, HORARIA (%)  \
# Data e Hora BR
# 31/12/2019 21:00                                 0.97
# 31/12/2019 22:00                                 0.88
# 31/12/2019 23:00                                 0.88
# 01/01/2020 00:00                                 0.83
# 01/01/2020 01:00                                 0.89
# ...                                               ...
# 31/12/2020 16:00                                 0.97
# 31/12/2020 17:00                                 0.91
# 31/12/2020 18:00                                 0.89
# 31/12/2020 19:00                                 0.88
# 31/12/2020 20:00                                 0.94
#
#                   RADIACAO GLOBAL (Kj/m²)  \
# Data e Hora BR
# 31/12/2019 21:00                      0.0
# 31/12/2019 22:00                      2.9
# 31/12/2019 23:00                      1.6
# 01/01/2020 00:00                      0.6
# 01/01/2020 01:00                      0.0
# ...                                   ...
# 31/12/2020 16:00                    775.9
# 31/12/2020 17:00                    837.8
# 31/12/2020 18:00                    524.7
# 31/12/2020 19:00                    256.5
# 31/12/2020 20:00                      9.6
#
#                   VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# Data e Hora BR
# 31/12/2019 21:00                                  11.0
# 31/12/2019 22:00                                  10.0
# 31/12/2019 23:00                                 345.0
# 01/01/2020 00:00                                 332.0
# 01/01/2020 01:00                                 316.0
# ...                                                ...
# 31/12/2020 16:00                                  32.0
# 31/12/2020 17:00                                 355.0
# 31/12/2020 18:00                                 315.0
# 31/12/2020 19:00                                 291.0
# 31/12/2020 20:00                                 132.0
#
#                   VENTO, VELOCIDADE HORARIA (m/s)         Data e Hora
# Data e Hora BR
# 31/12/2019 21:00                              1.9 2020-01-01 00:00:00
# 31/12/2019 22:00                              1.3 2020-01-01 01:00:00
# 31/12/2019 23:00                              0.6 2020-01-01 02:00:00
# 01/01/2020 00:00                              1.5 2020-01-01 03:00:00
# 01/01/2020 01:00                              0.2 2020-01-01 04:00:00
# ...                                           ...                 ...
# 31/12/2020 16:00                              1.2 2020-12-31 19:00:00
# 31/12/2020 17:00                              0.8 2020-12-31 20:00:00
# 31/12/2020 18:00                              1.2 2020-12-31 21:00:00
# 31/12/2020 19:00                              0.9 2020-12-31 22:00:00
# 31/12/2020 20:00                              0.9 2020-12-31 23:00:00
#
# [8784 rows x 10 columns]>

# %%
import sqlite3

# %%
conn = sqlite3.connect('clima.db')
# cursor = conn.cursor()

# persistindo o DataFrame no banco de dados
df.to_sql('clima', conn, if_exists='replace')
# Out:
# 8784

# %%
cursor = conn.cursor()
cursor.execute('SELECT * FROM clima')

col_names = [description[0] for description in cursor.description]

# for row in rows:
#     print(row)

df_db = pd.DataFrame(cursor.fetchall(), columns=col_names)

df_db
# Out:
#         Data e Hora BR        Data Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     31/12/2019 21:00  01/01/2020    00:00                               0.6
# 1     31/12/2019 22:00  01/01/2020    01:00                               0.0
# 2     31/12/2019 23:00  01/01/2020    02:00                               0.0
# 3     01/01/2020 00:00  01/01/2020    03:00                               0.0
# 4     01/01/2020 01:00  01/01/2020    04:00                               0.0
# ...                ...         ...      ...                               ...
# 8779  31/12/2020 16:00  31/12/2020    19:00                               0.4
# 8780  31/12/2020 17:00  31/12/2020    20:00                               0.0
# 8781  31/12/2020 18:00  31/12/2020    21:00                               0.0
# 8782  31/12/2020 19:00  31/12/2020    22:00                               0.0
# 8783  31/12/2020 20:00  31/12/2020    23:00                               0.0
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             23.1
# 1                                             23.7
# 2                                             24.0
# 3                                             24.3
# 4                                             23.8
# ...                                            ...
# 8779                                          23.1
# 8780                                          24.2
# 8781                                          24.9
# 8782                                          24.2
# 8783                                          23.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     22.6
# 1                                     21.7
# 2                                     21.8
# 3                                     21.4
# 4                                     21.7
# ...                                    ...
# 8779                                  22.7
# 8780                                  22.7
# 8781                                  23.0
# 8782                                  22.1
# 8783                                  22.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                    0.97                      0.0
# 1                                    0.88                      2.9
# 2                                    0.88                      1.6
# 3                                    0.83                      0.6
# 4                                    0.89                      0.0
# ...                                   ...                      ...
# 8779                                 0.97                    775.9
# 8780                                 0.91                    837.8
# 8781                                 0.89                    524.7
# 8782                                 0.88                    256.5
# 8783                                 0.94                      9.6
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)  \
# 0                                     11.0                              1.9
# 1                                     10.0                              1.3
# 2                                    345.0                              0.6
# 3                                    332.0                              1.5
# 4                                    316.0                              0.2
# ...                                    ...                              ...
# 8779                                  32.0                              1.2
# 8780                                 355.0                              0.8
# 8781                                 315.0                              1.2
# 8782                                 291.0                              0.9
# 8783                                 132.0                              0.9
#
#               Data e Hora
# 0     2020-01-01 00:00:00
# 1     2020-01-01 01:00:00
# 2     2020-01-01 02:00:00
# 3     2020-01-01 03:00:00
# 4     2020-01-01 04:00:00
# ...                   ...
# 8779  2020-12-31 19:00:00
# 8780  2020-12-31 20:00:00
# 8781  2020-12-31 21:00:00
# 8782  2020-12-31 22:00:00
# 8783  2020-12-31 23:00:00
#
# [8784 rows x 11 columns]

# %% [markdown]
# # Qual foi a média de valores de uma coluna específica?

# %%
Média = print(f"A média da temperatura do ar - Bulbo Seco, Horária é {round(df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].mean(),2)} ºC")
# Out:
# A média da temperatura do ar - Bulbo Seco, Horária é 23.17 ºC

# %% [markdown]
# # Qual o total de registros após a limpeza dos dados?

# %%
Total = print(f"O total de registros após a limpeza dos dados é de {(df.shape)}")
# Out:
# O total de registros após a limpeza dos dados é de (8784, 10)

# %% [markdown]
# # Quais foram os valores máximos e mínimos identificados?

# %%
df.describe()
# Out:
#        PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# count                       8784.000000
# mean                           0.151480
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                           44.800000
# std                            1.375679
#
#        TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# count                                   8784.000000
# mean                                      23.172837
# min                                        0.000000
# 25%                                       19.500000
# 50%                                       23.100000
# 75%                                       27.100000
# max                                       40.600000
# std                                        5.725963
#
#        TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# count                           8784.000000
# mean                              15.201423
# min                                0.000000
# 25%                               12.400000
# 50%                               16.000000
# 75%                               19.300000
# max                               25.800000
# std                                5.592551
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  RADIACAO GLOBAL (Kj/m²)  \
# count                          8784.000000              8784.000000
# mean                              0.632725               759.334028
# min                               0.000000                 0.000000
# 25%                               0.490000                 0.000000
# 50%                               0.670000                23.100000
# 75%                               0.820000              1434.250000
# max                               1.000000              4085.400000
# std                               0.241409              1077.034129
#
#        VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, VELOCIDADE HORARIA (m/s)  \
# count                           8784.000000                      8784.000000
# mean                             184.889458                         1.939447
# min                                0.000000                         0.000000
# 25%                              133.000000                         0.900000
# 50%                              171.000000                         1.800000
# 75%                              254.000000                         2.800000
# max                              360.000000                        11.900000
# std                               81.784719                         1.405233
#
#                Data e Hora
# count                 8784
# mean   2020-07-01 23:30:00
# min    2020-01-01 00:00:00
# 25%    2020-04-01 11:45:00
# 50%    2020-07-01 23:30:00
# 75%    2020-10-01 11:15:00
# max    2020-12-31 23:00:00
# std                    NaN

# %% [markdown]
# # Quantos registros tinham valores nulos antes do tratamento?
#
# **8784, 9**

# %%
# Out:
# Data e Hora BR
# 31/12/2019 21:00    0.875969
# 31/12/2019 22:00    0.841085
# 31/12/2019 23:00    0.844961
# 01/01/2020 00:00    0.829457
# 01/01/2020 01:00    0.841085
#                       ...
# 31/12/2020 16:00    0.879845
# 31/12/2020 17:00    0.879845
# 31/12/2020 18:00    0.891473
# 31/12/2020 19:00    0.856589
# 31/12/2020 20:00    0.872093
# Name: TEMPERATURA DO PONTO DE ORVALHO (°C), Length: 8784, dtype: float64

# %% [markdown]
# # Quais visualizações forneceram as informações mais valiosas? Que padrões emergiram após a análise dos dados?

# %% [markdown]
# No gráfico de Temperatura do Ar x Umidade Relativa do Ar entendi que quanto menor a temperatura maior a umidade relativa do ar.
# Nos meses de maio/2020 até setembro/2020 demonstram ser os meses com menor temperatura e consequentemente menor umidade relativa do ar.
# O mês de janeiro demostra temperaturas mais quentes, entre 25º e 35º.

# %% [markdown]
# # Como o uso de SQL contribuiu para a organização dos resultados?

# %% [markdown]
# # De que forma os gráficos ajudaram na compreensão dos dados?

# %% [markdown]
# Os gráficos ilustram os dados e trazem uma melhor compreensão das informações pelo efeito visual que fazem. Então fica muito mais fácil entender e explicar as informações atráves deles.

# %% [markdown]
# # Qual foi o impacto da normalização de uma coluna específica?
#
# A normalização vai deixar toda a coluna geralmente entre 0 e 1.

# %%
# Normaliza os valores de uma coluna para o intervalo [0, 1]
df['TEMPERATURA DO PONTO DE ORVALHO (°C)'] = (df['TEMPERATURA DO PONTO DE ORVALHO (°C)'] - df['TEMPERATURA DO PONTO DE ORVALHO (°C)'].min()) / (df['TEMPERATURA DO PONTO DE ORVALHO (°C)'].max() - df['TEMPERATURA DO PONTO DE ORVALHO (°C)'].min())
df['TEMPERATURA DO PONTO DE ORVALHO (°C)']
# Out:
# Data e Hora BR
# 31/12/2019 21:00    0.875969
# 31/12/2019 22:00    0.841085
# 31/12/2019 23:00    0.844961
# 01/01/2020 00:00    0.829457
# 01/01/2020 01:00    0.841085
#                       ...
# 31/12/2020 16:00    0.879845
# 31/12/2020 17:00    0.879845
# 31/12/2020 18:00    0.891473
# 31/12/2020 19:00    0.856589
# 31/12/2020 20:00    0.872093
# Name: TEMPERATURA DO PONTO DE ORVALHO (°C), Length: 8784, dtype: float64
